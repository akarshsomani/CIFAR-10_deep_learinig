# %% [markdown]
# <a href="https://colab.research.google.com/github/akarshsomani/CIFAR-10_deep_learinig/blob/master/cifar10_cnn_Revised_increased_epochs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 39s 0us/step

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
#create and configure agumented image generator
from keras.preprocessing.image import ImageDataGenerator
#randomly shift image horizontally and vertically
datagen=ImageDataGenerator(width_shift_range=0.1,height_shift_range=0.1,horizontal_flip=True)
datagen.fit(x_train)

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit_generator(datagen.flow(x_train, y_train, batch_size=100), steps_per_epoch = x_train.shape[0]//100,
          epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=1,shuffle=True)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# 450/450 [==============================] - 29s 64ms/step - loss: 1.6873 - acc: 0.3869 - val_loss: 1.3692 - val_acc: 0.5060
#
# Epoch 00001: val_loss improved from inf to 1.36916, saving model to model.weights.best.hdf5
# Epoch 2/100
# 450/450 [==============================] - 25s 55ms/step - loss: 1.4076 - acc: 0.4923 - val_loss: 1.2986 - val_acc: 0.5302
#
# Epoch 00002: val_loss improved from 1.36916 to 1.29862, saving model to model.weights.best.hdf5
# Epoch 3/100
# 450/450 [==============================] - 25s 55ms/step - loss: 1.2997 - acc: 0.5332 - val_loss: 1.1110 - val_acc: 0.6022
#
# Epoch 00003: val_loss improved from 1.29862 to 1.11104, saving model to model.weights.best.hdf5
# Epoch 4/100
# 450/450 [==============================] - 25s 55ms/step - loss: 1.2342 - acc: 0.5591 - val_loss: 1.1717 - val_acc: 0.5798
#
# Epoch 00004: val_loss did not improve from 1.11104
# Epoch 5/100
# 450/450 [==============================] - 25s 55ms/step - loss: 1.1796 - acc: 0.5800 - val_loss: 1.0108 - val_acc: 0.6370
#
# Epoch 00005: val_loss improved from 1.11104 to 1.01077, saving model to model.weights.best.hdf5
# Epoch 6/100
# 450/450 [==============================] - 24s 54ms/step - loss: 1.1333 - acc: 0.5950 - val_loss: 1.0187 - val_acc: 0.6438
#
# Epoch 00006: val_loss did not improve from 1.01077
# Epoch 7/100
# 450/450 [==============================] - 25s 55ms/step - loss: 1.0956 - acc: 0.6081 - val_loss: 0.9793 - val_acc: 0.6516
#
# Epoch 00007: val_loss improved from 1.01077 to 0.97926, saving model to model.weights.best.hdf5
# Epoch 8/100
# 450/450 [==============================] - 25s 55ms/step - loss: 1.0608 - acc: 0.6243 - val_loss: 0.9103 - val_acc: 0.6728
#
# Epoch 00008: val_loss improved from 0.97926 to 0.91031, saving model to model.weights.best.hdf5
# Epoch 9/100
# 450/450 [==============================] - 25s 55ms/step - loss: 1.0341 - acc: 0.6346 - val_loss: 0.9145 - val_acc: 0.6864
#
# Epoch 00009: val_loss did not improve from 0.91031
# Epoch 10/100
# 450/450 [==============================] - 24s 54ms/step - loss: 1.0042 - acc: 0.6472 - val_loss: 0.8825 - val_acc: 0.6906
#
# Epoch 00010: val_loss improved from 0.91031 to 0.88253, saving model to model.weights.best.hdf5
# Epoch 11/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.9782 - acc: 0.6561 - val_loss: 0.8751 - val_acc: 0.6790
#
# Epoch 00011: val_loss improved from 0.88253 to 0.87505, saving model to model.weights.best.hdf5
# Epoch 12/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.9532 - acc: 0.6629 - val_loss: 0.8530 - val_acc: 0.7034
#
# Epoch 00012: val_loss improved from 0.87505 to 0.85298, saving model to model.weights.best.hdf5
# Epoch 13/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.9312 - acc: 0.6703 - val_loss: 0.8256 - val_acc: 0.7072
#
# Epoch 00013: val_loss improved from 0.85298 to 0.82556, saving model to model.weights.best.hdf5
# Epoch 14/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.9163 - acc: 0.6756 - val_loss: 0.8414 - val_acc: 0.7056
#
# Epoch 00014: val_loss did not improve from 0.82556
# Epoch 15/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.8973 - acc: 0.6836 - val_loss: 0.7916 - val_acc: 0.7154
#
# Epoch 00015: val_loss improved from 0.82556 to 0.79156, saving model to model.weights.best.hdf5
# Epoch 16/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.8816 - acc: 0.6874 - val_loss: 0.8286 - val_acc: 0.7042
#
# Epoch 00016: val_loss did not improve from 0.79156
# Epoch 17/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.8696 - acc: 0.6933 - val_loss: 0.7993 - val_acc: 0.7144
#
# Epoch 00017: val_loss did not improve from 0.79156
# Epoch 18/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.8588 - acc: 0.6988 - val_loss: 0.7774 - val_acc: 0.7176
#
# Epoch 00018: val_loss improved from 0.79156 to 0.77740, saving model to model.weights.best.hdf5
# Epoch 19/100
# 450/450 [==============================] - 24s 53ms/step - loss: 0.8353 - acc: 0.7046 - val_loss: 0.7547 - val_acc: 0.7316
#
# Epoch 00019: val_loss improved from 0.77740 to 0.75469, saving model to model.weights.best.hdf5
# Epoch 20/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.8337 - acc: 0.7074 - val_loss: 0.7375 - val_acc: 0.7384
#
# Epoch 00020: val_loss improved from 0.75469 to 0.73745, saving model to model.weights.best.hdf5
# Epoch 21/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.8200 - acc: 0.7110 - val_loss: 0.7294 - val_acc: 0.7396
#
# Epoch 00021: val_loss improved from 0.73745 to 0.72939, saving model to model.weights.best.hdf5
# Epoch 22/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.8079 - acc: 0.7187 - val_loss: 0.7052 - val_acc: 0.7502
#
# Epoch 00022: val_loss improved from 0.72939 to 0.70522, saving model to model.weights.best.hdf5
# Epoch 23/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.7997 - acc: 0.7175 - val_loss: 0.7328 - val_acc: 0.7400
#
# Epoch 00023: val_loss did not improve from 0.70522
# Epoch 24/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.7894 - acc: 0.7206 - val_loss: 0.7253 - val_acc: 0.7434
#
# Epoch 00024: val_loss did not improve from 0.70522
# Epoch 25/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.7792 - acc: 0.7270 - val_loss: 0.6879 - val_acc: 0.7660
#
# Epoch 00025: val_loss improved from 0.70522 to 0.68787, saving model to model.weights.best.hdf5
# Epoch 26/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.7726 - acc: 0.7304 - val_loss: 0.6906 - val_acc: 0.7568
#
# Epoch 00026: val_loss did not improve from 0.68787
# Epoch 27/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.7628 - acc: 0.7316 - val_loss: 0.7004 - val_acc: 0.7524
#
# Epoch 00027: val_loss did not improve from 0.68787
# Epoch 28/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.7572 - acc: 0.7314 - val_loss: 0.6642 - val_acc: 0.7686
#
# Epoch 00028: val_loss improved from 0.68787 to 0.66421, saving model to model.weights.best.hdf5
# Epoch 29/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.7530 - acc: 0.7344 - val_loss: 0.6690 - val_acc: 0.7638
#
# Epoch 00029: val_loss did not improve from 0.66421
# Epoch 30/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.7371 - acc: 0.7401 - val_loss: 0.6748 - val_acc: 0.7614
#
# Epoch 00030: val_loss did not improve from 0.66421
# Epoch 31/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.7378 - acc: 0.7382 - val_loss: 0.6753 - val_acc: 0.7634
#
# Epoch 00031: val_loss did not improve from 0.66421
# Epoch 32/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.7352 - acc: 0.7411 - val_loss: 0.6663 - val_acc: 0.7678
#
# Epoch 00032: val_loss did not improve from 0.66421
# Epoch 33/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.7233 - acc: 0.7437 - val_loss: 0.7117 - val_acc: 0.7464
#
# Epoch 00033: val_loss did not improve from 0.66421
# Epoch 34/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.7219 - acc: 0.7446 - val_loss: 0.6823 - val_acc: 0.7616
#
# Epoch 00034: val_loss did not improve from 0.66421
# Epoch 35/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.7137 - acc: 0.7492 - val_loss: 0.6561 - val_acc: 0.7712
#
# Epoch 00035: val_loss improved from 0.66421 to 0.65614, saving model to model.weights.best.hdf5
# Epoch 36/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.7069 - acc: 0.7508 - val_loss: 0.6812 - val_acc: 0.7598
#
# Epoch 00036: val_loss did not improve from 0.65614
# Epoch 37/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.7039 - acc: 0.7510 - val_loss: 0.6568 - val_acc: 0.7682
#
# Epoch 00037: val_loss did not improve from 0.65614
# Epoch 38/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.6983 - acc: 0.7532 - val_loss: 0.6330 - val_acc: 0.7854
#
# Epoch 00038: val_loss improved from 0.65614 to 0.63297, saving model to model.weights.best.hdf5
# Epoch 39/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.6913 - acc: 0.7567 - val_loss: 0.6789 - val_acc: 0.7560
#
# Epoch 00039: val_loss did not improve from 0.63297
# Epoch 40/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.6912 - acc: 0.7557 - val_loss: 0.6480 - val_acc: 0.7698
#
# Epoch 00040: val_loss did not improve from 0.63297
# Epoch 41/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.6860 - acc: 0.7569 - val_loss: 0.6557 - val_acc: 0.7704
#
# Epoch 00041: val_loss did not improve from 0.63297
# Epoch 42/100
# 450/450 [==============================] - 25s 56ms/step - loss: 0.6809 - acc: 0.7600 - val_loss: 0.6264 - val_acc: 0.7878
#
# Epoch 00042: val_loss improved from 0.63297 to 0.62639, saving model to model.weights.best.hdf5
# Epoch 43/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.6748 - acc: 0.7596 - val_loss: 0.6622 - val_acc: 0.7686
#
# Epoch 00043: val_loss did not improve from 0.62639
# Epoch 44/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.6732 - acc: 0.7620 - val_loss: 0.7001 - val_acc: 0.7518
#
# Epoch 00044: val_loss did not improve from 0.62639
# Epoch 45/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.6664 - acc: 0.7663 - val_loss: 0.6221 - val_acc: 0.7864
#
# Epoch 00045: val_loss improved from 0.62639 to 0.62208, saving model to model.weights.best.hdf5
# Epoch 46/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.6638 - acc: 0.7632 - val_loss: 0.6447 - val_acc: 0.7740
#
# Epoch 00046: val_loss did not improve from 0.62208
# Epoch 47/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.6590 - acc: 0.7670 - val_loss: 0.6064 - val_acc: 0.7944
#
# Epoch 00047: val_loss improved from 0.62208 to 0.60644, saving model to model.weights.best.hdf5
# Epoch 48/100
# 450/450 [==============================] - 25s 56ms/step - loss: 0.6651 - acc: 0.7650 - val_loss: 0.6219 - val_acc: 0.7860
#
# Epoch 00048: val_loss did not improve from 0.60644
# Epoch 49/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.6502 - acc: 0.7709 - val_loss: 0.6242 - val_acc: 0.7860
#
# Epoch 00049: val_loss did not improve from 0.60644
# Epoch 50/100
# 450/450 [==============================] - 25s 56ms/step - loss: 0.6450 - acc: 0.7704 - val_loss: 0.6280 - val_acc: 0.7852
#
# Epoch 00050: val_loss did not improve from 0.60644
# Epoch 51/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.6503 - acc: 0.7707 - val_loss: 0.6600 - val_acc: 0.7802
#
# Epoch 00051: val_loss did not improve from 0.60644
# Epoch 52/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.6488 - acc: 0.7714 - val_loss: 0.6576 - val_acc: 0.7698
#
# Epoch 00052: val_loss did not improve from 0.60644
# Epoch 53/100
# 450/450 [==============================] - 25s 56ms/step - loss: 0.6447 - acc: 0.7709 - val_loss: 0.6260 - val_acc: 0.7806
#
# Epoch 00053: val_loss did not improve from 0.60644
# Epoch 54/100
# 450/450 [==============================] - 25s 56ms/step - loss: 0.6391 - acc: 0.7741 - val_loss: 0.6160 - val_acc: 0.7824
#
# Epoch 00054: val_loss did not improve from 0.60644
# Epoch 55/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.6348 - acc: 0.7738 - val_loss: 0.5995 - val_acc: 0.7922
#
# Epoch 00055: val_loss improved from 0.60644 to 0.59955, saving model to model.weights.best.hdf5
# Epoch 56/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.6331 - acc: 0.7742 - val_loss: 0.6505 - val_acc: 0.7710
#
# Epoch 00056: val_loss did not improve from 0.59955
# Epoch 57/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.6265 - acc: 0.7795 - val_loss: 0.6168 - val_acc: 0.7886
#
# Epoch 00057: val_loss did not improve from 0.59955
# Epoch 58/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.6234 - acc: 0.7776 - val_loss: 0.6479 - val_acc: 0.7764
#
# Epoch 00058: val_loss did not improve from 0.59955
# Epoch 59/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.6269 - acc: 0.7753 - val_loss: 0.6078 - val_acc: 0.7888
#
# Epoch 00059: val_loss did not improve from 0.59955
# Epoch 60/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.6250 - acc: 0.7788 - val_loss: 0.6278 - val_acc: 0.7858
#
# Epoch 00060: val_loss did not improve from 0.59955
# Epoch 61/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.6175 - acc: 0.7814 - val_loss: 0.5992 - val_acc: 0.7924
#
# Epoch 00061: val_loss improved from 0.59955 to 0.59917, saving model to model.weights.best.hdf5
# Epoch 62/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.6160 - acc: 0.7844 - val_loss: 0.6193 - val_acc: 0.7810
#
# Epoch 00062: val_loss did not improve from 0.59917
# Epoch 63/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.6145 - acc: 0.7831 - val_loss: 0.6046 - val_acc: 0.7932
#
# Epoch 00063: val_loss did not improve from 0.59917
# Epoch 64/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.6177 - acc: 0.7808 - val_loss: 0.6124 - val_acc: 0.7854
#
# Epoch 00064: val_loss did not improve from 0.59917
# Epoch 65/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.6107 - acc: 0.7838 - val_loss: 0.5939 - val_acc: 0.7914
#
# Epoch 00065: val_loss improved from 0.59917 to 0.59392, saving model to model.weights.best.hdf5
# Epoch 66/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.6102 - acc: 0.7815 - val_loss: 0.5926 - val_acc: 0.7988
#
# Epoch 00066: val_loss improved from 0.59392 to 0.59257, saving model to model.weights.best.hdf5
# Epoch 67/100
# 450/450 [==============================] - 24s 53ms/step - loss: 0.6082 - acc: 0.7866 - val_loss: 0.6240 - val_acc: 0.7860
#
# Epoch 00067: val_loss did not improve from 0.59257
# Epoch 68/100
# 450/450 [==============================] - 24s 53ms/step - loss: 0.6077 - acc: 0.7851 - val_loss: 0.5948 - val_acc: 0.7962
#
# Epoch 00068: val_loss did not improve from 0.59257
# Epoch 69/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.6013 - acc: 0.7866 - val_loss: 0.6287 - val_acc: 0.7832
#
# Epoch 00069: val_loss did not improve from 0.59257
# Epoch 70/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.6025 - acc: 0.7848 - val_loss: 0.6079 - val_acc: 0.7832
#
# Epoch 00070: val_loss did not improve from 0.59257
# Epoch 71/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.5962 - acc: 0.7909 - val_loss: 0.6062 - val_acc: 0.7896
#
# Epoch 00071: val_loss did not improve from 0.59257
# Epoch 72/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.5951 - acc: 0.7893 - val_loss: 0.6389 - val_acc: 0.7794
#
# Epoch 00072: val_loss did not improve from 0.59257
# Epoch 73/100
# 450/450 [==============================] - 24s 53ms/step - loss: 0.5938 - acc: 0.7880 - val_loss: 0.6296 - val_acc: 0.7826
#
# Epoch 00073: val_loss did not improve from 0.59257
# Epoch 74/100
# 450/450 [==============================] - 24s 53ms/step - loss: 0.5927 - acc: 0.7895 - val_loss: 0.6285 - val_acc: 0.7846
#
# Epoch 00074: val_loss did not improve from 0.59257
# Epoch 75/100
# 450/450 [==============================] - 24s 53ms/step - loss: 0.5882 - acc: 0.7926 - val_loss: 0.6060 - val_acc: 0.7916
#
# Epoch 00075: val_loss did not improve from 0.59257
# Epoch 76/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.5828 - acc: 0.7915 - val_loss: 0.5949 - val_acc: 0.7946
#
# Epoch 00076: val_loss did not improve from 0.59257
# Epoch 77/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.5869 - acc: 0.7930 - val_loss: 0.6063 - val_acc: 0.7930
#
# Epoch 00077: val_loss did not improve from 0.59257
# Epoch 78/100
# 450/450 [==============================] - 24s 53ms/step - loss: 0.5830 - acc: 0.7917 - val_loss: 0.6181 - val_acc: 0.7906
#
# Epoch 00078: val_loss did not improve from 0.59257
# Epoch 79/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.5834 - acc: 0.7938 - val_loss: 0.5958 - val_acc: 0.7998
#
# Epoch 00079: val_loss did not improve from 0.59257
# Epoch 80/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.5826 - acc: 0.7931 - val_loss: 0.5892 - val_acc: 0.7998
#
# Epoch 00080: val_loss improved from 0.59257 to 0.58923, saving model to model.weights.best.hdf5
# Epoch 81/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.5781 - acc: 0.7950 - val_loss: 0.5913 - val_acc: 0.7952
#
# Epoch 00081: val_loss did not improve from 0.58923
# Epoch 82/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.5829 - acc: 0.7927 - val_loss: 0.5858 - val_acc: 0.7992
#
# Epoch 00082: val_loss improved from 0.58923 to 0.58581, saving model to model.weights.best.hdf5
# Epoch 83/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.5811 - acc: 0.7942 - val_loss: 0.5837 - val_acc: 0.7976
#
# Epoch 00083: val_loss improved from 0.58581 to 0.58372, saving model to model.weights.best.hdf5
# Epoch 84/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.5751 - acc: 0.7935 - val_loss: 0.6176 - val_acc: 0.7852
#
# Epoch 00084: val_loss did not improve from 0.58372
# Epoch 85/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.5670 - acc: 0.7973 - val_loss: 0.6124 - val_acc: 0.7874
#
# Epoch 00085: val_loss did not improve from 0.58372
# Epoch 86/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.5666 - acc: 0.7993 - val_loss: 0.5906 - val_acc: 0.8046
#
# Epoch 00086: val_loss did not improve from 0.58372
# Epoch 87/100
# 450/450 [==============================] - 24s 53ms/step - loss: 0.5636 - acc: 0.7991 - val_loss: 0.5736 - val_acc: 0.8034
#
# Epoch 00087: val_loss improved from 0.58372 to 0.57360, saving model to model.weights.best.hdf5
# Epoch 88/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.5709 - acc: 0.7987 - val_loss: 0.5829 - val_acc: 0.7936
#
# Epoch 00088: val_loss did not improve from 0.57360
# Epoch 89/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.5665 - acc: 0.7985 - val_loss: 0.5827 - val_acc: 0.8002
#
# Epoch 00089: val_loss did not improve from 0.57360
# Epoch 90/100
# 450/450 [==============================] - 24s 53ms/step - loss: 0.5609 - acc: 0.8020 - val_loss: 0.6192 - val_acc: 0.7888
#
# Epoch 00090: val_loss did not improve from 0.57360
# Epoch 91/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.5685 - acc: 0.7967 - val_loss: 0.5845 - val_acc: 0.8004
#
# Epoch 00091: val_loss did not improve from 0.57360
# Epoch 92/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.5611 - acc: 0.8007 - val_loss: 0.5993 - val_acc: 0.7922
#
# Epoch 00092: val_loss did not improve from 0.57360
# Epoch 93/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.5577 - acc: 0.8020 - val_loss: 0.6701 - val_acc: 0.7714
#
# Epoch 00093: val_loss did not improve from 0.57360
# Epoch 94/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.5632 - acc: 0.8007 - val_loss: 0.6209 - val_acc: 0.7930
#
# Epoch 00094: val_loss did not improve from 0.57360
# Epoch 95/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.5553 - acc: 0.8016 - val_loss: 0.6451 - val_acc: 0.7838
#
# Epoch 00095: val_loss did not improve from 0.57360
# Epoch 96/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.5554 - acc: 0.8018 - val_loss: 0.6060 - val_acc: 0.7914
#
# Epoch 00096: val_loss did not improve from 0.57360
# Epoch 97/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.5503 - acc: 0.8047 - val_loss: 0.5931 - val_acc: 0.7946
#
# Epoch 00097: val_loss did not improve from 0.57360
# Epoch 98/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.5522 - acc: 0.8031 - val_loss: 0.6177 - val_acc: 0.7858
#
# Epoch 00098: val_loss did not improve from 0.57360
# Epoch 99/100
# 450/450 [==============================] - 25s 55ms/step - loss: 0.5588 - acc: 0.8016 - val_loss: 0.6383 - val_acc: 0.7806
#
# Epoch 00099: val_loss did not improve from 0.57360
# Epoch 100/100
# 450/450 [==============================] - 24s 54ms/step - loss: 0.5445 - acc: 0.8077 - val_loss: 0.6157 - val_acc: 0.7884
#
# Epoch 00100: val_loss did not improve from 0.57360

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.7904

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
